# %%
import os
import torch
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from PIL import Image
from torchvision.models import vit_b_16
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import cv2
import numpy as np
import os

import wandb

# %run helpFunction.ipynb
# Out:
# \begin{table}
# \caption{Test Klassifikations Metriken}
# \label{tab:model_performance}
# \begin{tabular}{llllr}
# \toprule
# Modell & Accuracy & Precision & Recall & F1-Score \\
# \midrule
# ViT & 83\% & 83\% & 83\% & 83.000000 \\
# Hybridmodel - ViT - DeiT & 82\% & 82\% & 82\% & 82.000000 \\
# Hybridmodel - ViT Lite - DeiT & 82\% & 82\% & 82\% & 82.000000 \\
# InceptionV3 & 82\% & 83\% & 82\% & 82.000000 \\
# DeiT & 81\% & 81\% & 82\% & 81.000000 \\
# ViT Lite & 79\% & 79\% & 79\% & 79.000000 \\
# Basic CNN & 78\% & 80\% & 78\% & 78.000000 \\
# \bottomrule
# \end{tabular}
# \end{table}
# /var/folders/rg/wpq9g3gn2_sg42m9vzpp7flw0000gn/T/ipykernel_3042/1995663629.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Modell').apply(lambda x: x.nlargest(1, 'F1-Score')).reset_index(drop=True)

# %%
wandb.init(project="VisionTransformer")
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: silvan-wiedmer (silvan-wiedmer-fhgr). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>/Users/silvanwiedmer/Desktop/VisionTransformer/model/wandb/run-20241027_191111-l4ml5pna</code>
# Syncing run <strong><a href='https://wandb.ai/silvan-wiedmer-fhgr/VisionTransformer/runs/l4ml5pna' target="_blank">fancy-gorge-454</a></strong> to <a href='https://wandb.ai/silvan-wiedmer-fhgr/VisionTransformer' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/silvan-wiedmer-fhgr/VisionTransformer' target="_blank">https://wandb.ai/silvan-wiedmer-fhgr/VisionTransformer</a>
#  View run at <a href='https://wandb.ai/silvan-wiedmer-fhgr/VisionTransformer/runs/l4ml5pna' target="_blank">https://wandb.ai/silvan-wiedmer-fhgr/VisionTransformer/runs/l4ml5pna</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/silvan-wiedmer-fhgr/VisionTransformer/runs/l4ml5pna?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def apply_canny(image, image_size):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    tight = cv2.Canny(blurred, 140, 160)
    tight = cv2.resize(tight, image_size)
    tight = np.expand_dims(tight, axis=-1)
    return tight

def apply_morphology(image, target_size):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 190, 210, cv2.THRESH_BINARY)
    kernel = np.ones((5,5), np.uint8)
    dilated = cv2.dilate(thresh, kernel, iterations=1)
    eroded = cv2.erode(dilated, kernel, iterations=1)
    image = cv2.resize(eroded, target_size)
    image = np.expand_dims(image, axis=-1)
    return image

def black_and_white(image, target_size):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, target_size)
    image = np.expand_dims(image, axis=-1)
    return image

# %%
class VerkehrsschilderDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []

        for label, subfolder in enumerate(['y', 'n']):
            folder_path = os.path.join(self.root_dir, subfolder)
            for image_name in os.listdir(folder_path):
                self.images.append(os.path.join(folder_path, image_name))
                self.labels.append(label)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        label = self.labels[idx]
        image = cv2.imread(image_path)

        canny_image = apply_canny(image, (224, 224))
        morphology_image = apply_morphology(image, (224, 224))
        bw_image = black_and_white(image, (224, 224))

        combined_image = np.concatenate((canny_image, morphology_image, bw_image), axis=-1)

        combined_image = Image.fromarray(np.uint8(combined_image))
        if self.transform:
            combined_image = self.transform(combined_image)

        return combined_image, label


transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomGrayscale(p=0.2),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Dataset erstellen
dataset = VerkehrsschilderDataset('../data', transform=transform)

total_count = len(dataset)
train_count = int(0.7 * total_count)
valid_count = int(0.15 * total_count)
test_count = total_count - train_count - valid_count  # Adjust to ensure all data is used

train_dataset, valid_dataset, test_dataset = random_split(dataset, [train_count, valid_count, test_count])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
class_names = ['Wartelinie', 'keine Wartelinie']

# %%
print(total_count)
VerkehrsschilderDataset.__getitem__(dataset, 900)
# Out:
# 1456
# (tensor([[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           ...,
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#          [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           ...,
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]]),
#  1)

# %%
def show_image(image, label):
    plt.imshow(np.transpose(image.numpy(), (1, 2, 0)))
    plt.title('Label: ' + ('Haifisch' if label == 0 else 'keine Haifisch'))
    plt.show()

show_image(VerkehrsschilderDataset.__getitem__(dataset, 900)[0], VerkehrsschilderDataset.__getitem__(dataset, 900)[1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.3959913].

# %%
model = vit_b_16(pretrained=True)
num_attention_heads = model.encoder.layers[0].self_attention.num_heads
print(f'Number of Attention Heads: {num_attention_heads}')
# Out:
# /Users/silvanwiedmer/Desktop/VisionTransformer/.venv/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/silvanwiedmer/Desktop/VisionTransformer/.venv/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /Users/silvanwiedmer/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100.0%
# Number of Attention Heads: 12

# %%
class CustomViT(nn.Module):
    def __init__(self):
        super(CustomViT, self).__init__()

        self.vit = vit_b_16(pretrained=True)
        
        self.num_features = self.vit.heads[0].in_features

        self.vit.heads[0] = nn.Identity()

        self.fc1 = nn.Linear(self.num_features, self.num_features)
        self.bn1 = nn.BatchNorm1d(self.num_features)
        self.relu = nn.ReLU()
        self.dropout2 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(self.num_features, 2)

    def forward(self, x):
        x = self.vit(x)  
        x = self.fc1(x)
        x = self.bn1(x)  
        x = self.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        return x

# %%
model = CustomViT()

device = torch.device("cpu")

if torch.cuda.is_available():
    device = torch.device("cuda")

if torch.backends.mps.is_available():
    device = torch.device("mps")

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc2.parameters(), lr=0.001, weight_decay=0.01)  # Adding weight decay
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
for name, module in model.named_modules():
    print(name)
# Out:
# vit
# vit.conv_proj
# vit.encoder
# vit.encoder.dropout
# vit.encoder.layers
# vit.encoder.layers.encoder_layer_0
# vit.encoder.layers.encoder_layer_0.ln_1
# vit.encoder.layers.encoder_layer_0.self_attention
# vit.encoder.layers.encoder_layer_0.self_attention.out_proj
# vit.encoder.layers.encoder_layer_0.dropout
# vit.encoder.layers.encoder_layer_0.ln_2
# vit.encoder.layers.encoder_layer_0.mlp
# vit.encoder.layers.encoder_layer_0.mlp.0
# vit.encoder.layers.encoder_layer_0.mlp.1
# vit.encoder.layers.encoder_layer_0.mlp.2
# vit.encoder.layers.encoder_layer_0.mlp.3
# vit.encoder.layers.encoder_layer_0.mlp.4
# vit.encoder.layers.encoder_layer_1
# vit.encoder.layers.encoder_layer_1.ln_1
# vit.encoder.layers.encoder_layer_1.self_attention
# vit.encoder.layers.encoder_layer_1.self_attention.out_proj
# vit.encoder.layers.encoder_layer_1.dropout
# vit.encoder.layers.encoder_layer_1.ln_2
# vit.encoder.layers.encoder_layer_1.mlp
# vit.encoder.layers.encoder_layer_1.mlp.0
# vit.encoder.layers.encoder_layer_1.mlp.1
# vit.encoder.layers.encoder_layer_1.mlp.2
# vit.encoder.layers.encoder_layer_1.mlp.3
# vit.encoder.layers.encoder_layer_1.mlp.4
# vit.encoder.layers.encoder_layer_2
# vit.encoder.layers.encoder_layer_2.ln_1
# vit.encoder.layers.encoder_layer_2.self_attention
# vit.encoder.layers.encoder_layer_2.self_attention.out_proj
# vit.encoder.layers.encoder_layer_2.dropout
# vit.encoder.layers.encoder_layer_2.ln_2
# vit.encoder.layers.encoder_layer_2.mlp
# vit.encoder.layers.encoder_layer_2.mlp.0
# vit.encoder.layers.encoder_layer_2.mlp.1
# vit.encoder.layers.encoder_layer_2.mlp.2
# vit.encoder.layers.encoder_layer_2.mlp.3
# vit.encoder.layers.encoder_layer_2.mlp.4
# vit.encoder.layers.encoder_layer_3
# vit.encoder.layers.encoder_layer_3.ln_1
# vit.encoder.layers.encoder_layer_3.self_attention
# vit.encoder.layers.encoder_layer_3.self_attention.out_proj
# vit.encoder.layers.encoder_layer_3.dropout
# vit.encoder.layers.encoder_layer_3.ln_2
# vit.encoder.layers.encoder_layer_3.mlp
# vit.encoder.layers.encoder_layer_3.mlp.0
# vit.encoder.layers.encoder_layer_3.mlp.1
# vit.encoder.layers.encoder_layer_3.mlp.2
# vit.encoder.layers.encoder_layer_3.mlp.3
# vit.encoder.layers.encoder_layer_3.mlp.4
# vit.encoder.layers.encoder_layer_4
# vit.encoder.layers.encoder_layer_4.ln_1
# vit.encoder.layers.encoder_layer_4.self_attention
# vit.encoder.layers.encoder_layer_4.self_attention.out_proj
# vit.encoder.layers.encoder_layer_4.dropout
# vit.encoder.layers.encoder_layer_4.ln_2
# vit.encoder.layers.encoder_layer_4.mlp
# vit.encoder.layers.encoder_layer_4.mlp.0
# vit.encoder.layers.encoder_layer_4.mlp.1
# vit.encoder.layers.encoder_layer_4.mlp.2
# vit.encoder.layers.encoder_layer_4.mlp.3
# vit.encoder.layers.encoder_layer_4.mlp.4
# vit.encoder.layers.encoder_layer_5
# vit.encoder.layers.encoder_layer_5.ln_1
# vit.encoder.layers.encoder_layer_5.self_attention
# vit.encoder.layers.encoder_layer_5.self_attention.out_proj
# vit.encoder.layers.encoder_layer_5.dropout
# vit.encoder.layers.encoder_layer_5.ln_2
# vit.encoder.layers.encoder_layer_5.mlp
# vit.encoder.layers.encoder_layer_5.mlp.0
# vit.encoder.layers.encoder_layer_5.mlp.1
# vit.encoder.layers.encoder_layer_5.mlp.2
# vit.encoder.layers.encoder_layer_5.mlp.3
# vit.encoder.layers.encoder_layer_5.mlp.4
# vit.encoder.layers.encoder_layer_6
# vit.encoder.layers.encoder_layer_6.ln_1
# vit.encoder.layers.encoder_layer_6.self_attention
# vit.encoder.layers.encoder_layer_6.self_attention.out_proj
# vit.encoder.layers.encoder_layer_6.dropout
# vit.encoder.layers.encoder_layer_6.ln_2
# vit.encoder.layers.encoder_layer_6.mlp
# vit.encoder.layers.encoder_layer_6.mlp.0
# vit.encoder.layers.encoder_layer_6.mlp.1
# vit.encoder.layers.encoder_layer_6.mlp.2
# vit.encoder.layers.encoder_layer_6.mlp.3
# vit.encoder.layers.encoder_layer_6.mlp.4
# vit.encoder.layers.encoder_layer_7
# vit.encoder.layers.encoder_layer_7.ln_1
# vit.encoder.layers.encoder_layer_7.self_attention
# vit.encoder.layers.encoder_layer_7.self_attention.out_proj
# vit.encoder.layers.encoder_layer_7.dropout
# vit.encoder.layers.encoder_layer_7.ln_2
# vit.encoder.layers.encoder_layer_7.mlp
# vit.encoder.layers.encoder_layer_7.mlp.0
# vit.encoder.layers.encoder_layer_7.mlp.1
# vit.encoder.layers.encoder_layer_7.mlp.2
# vit.encoder.layers.encoder_layer_7.mlp.3
# vit.encoder.layers.encoder_layer_7.mlp.4
# vit.encoder.layers.encoder_layer_8
# vit.encoder.layers.encoder_layer_8.ln_1
# vit.encoder.layers.encoder_layer_8.self_attention
# vit.encoder.layers.encoder_layer_8.self_attention.out_proj
# vit.encoder.layers.encoder_layer_8.dropout
# vit.encoder.layers.encoder_layer_8.ln_2
# vit.encoder.layers.encoder_layer_8.mlp
# vit.encoder.layers.encoder_layer_8.mlp.0
# vit.encoder.layers.encoder_layer_8.mlp.1
# vit.encoder.layers.encoder_layer_8.mlp.2
# vit.encoder.layers.encoder_layer_8.mlp.3
# vit.encoder.layers.encoder_layer_8.mlp.4
# vit.encoder.layers.encoder_layer_9
# vit.encoder.layers.encoder_layer_9.ln_1
# vit.encoder.layers.encoder_layer_9.self_attention
# vit.encoder.layers.encoder_layer_9.self_attention.out_proj
# vit.encoder.layers.encoder_layer_9.dropout
# vit.encoder.layers.encoder_layer_9.ln_2
# vit.encoder.layers.encoder_layer_9.mlp
# vit.encoder.layers.encoder_layer_9.mlp.0
# vit.encoder.layers.encoder_layer_9.mlp.1
# vit.encoder.layers.encoder_layer_9.mlp.2
# vit.encoder.layers.encoder_layer_9.mlp.3
# vit.encoder.layers.encoder_layer_9.mlp.4
# vit.encoder.layers.encoder_layer_10
# vit.encoder.layers.encoder_layer_10.ln_1
# vit.encoder.layers.encoder_layer_10.self_attention
# vit.encoder.layers.encoder_layer_10.self_attention.out_proj
# vit.encoder.layers.encoder_layer_10.dropout
# vit.encoder.layers.encoder_layer_10.ln_2
# vit.encoder.layers.encoder_layer_10.mlp
# vit.encoder.layers.encoder_layer_10.mlp.0
# vit.encoder.layers.encoder_layer_10.mlp.1
# vit.encoder.layers.encoder_layer_10.mlp.2
# vit.encoder.layers.encoder_layer_10.mlp.3
# vit.encoder.layers.encoder_layer_10.mlp.4
# vit.encoder.layers.encoder_layer_11
# vit.encoder.layers.encoder_layer_11.ln_1
# vit.encoder.layers.encoder_layer_11.self_attention
# vit.encoder.layers.encoder_layer_11.self_attention.out_proj
# vit.encoder.layers.encoder_layer_11.dropout
# vit.encoder.layers.encoder_layer_11.ln_2
# vit.encoder.layers.encoder_layer_11.mlp
# vit.encoder.layers.encoder_layer_11.mlp.0
# vit.encoder.layers.encoder_layer_11.mlp.1
# vit.encoder.layers.encoder_layer_11.mlp.2
# vit.encoder.layers.encoder_layer_11.mlp.3
# vit.encoder.layers.encoder_layer_11.mlp.4
# vit.encoder.ln
# vit.heads
# vit.heads.head
# fc1
# bn1
# relu
# dropout2
# fc2

# %%
# Überprüfen der Modellarchitektur
for name, module in model.named_modules():
    print(name, type(module))
# Out:
#  <class '__main__.CustomViT'>
# vit <class 'torchvision.models.vision_transformer.VisionTransformer'>
# vit.conv_proj <class 'torch.nn.modules.conv.Conv2d'>
# vit.encoder <class 'torchvision.models.vision_transformer.Encoder'>
# vit.encoder.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers <class 'torch.nn.modules.container.Sequential'>
# vit.encoder.layers.encoder_layer_0 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_0.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_0.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_0.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_0.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_0.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_0.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_0.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_0.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_0.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_0.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_0.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_1 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_1.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_1.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_1.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_1.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_1.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_1.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_1.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_1.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_1.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_1.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_1.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_2 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_2.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_2.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_2.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_2.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_2.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_2.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_2.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_2.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_2.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_2.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_2.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_3 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_3.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_3.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_3.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_3.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_3.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_3.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_3.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_3.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_3.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_3.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_3.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_4 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_4.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_4.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_4.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_4.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_4.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_4.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_4.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_4.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_4.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_4.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_4.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_5 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_5.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_5.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_5.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_5.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_5.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_5.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_5.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_5.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_5.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_5.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_5.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_6 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_6.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_6.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_6.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_6.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_6.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_6.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_6.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_6.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_6.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_6.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_6.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_7 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_7.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_7.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_7.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_7.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_7.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_7.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_7.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_7.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_7.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_7.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_7.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_8 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_8.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_8.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_8.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_8.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_8.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_8.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_8.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_8.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_8.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_8.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_8.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_9 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_9.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_9.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_9.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_9.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_9.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_9.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_9.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_9.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_9.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_9.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_9.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_10 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_10.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_10.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_10.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_10.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_10.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_10.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_10.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_10.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_10.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_10.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_10.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_11 <class 'torchvision.models.vision_transformer.EncoderBlock'>
# vit.encoder.layers.encoder_layer_11.ln_1 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_11.self_attention <class 'torch.nn.modules.activation.MultiheadAttention'>
# vit.encoder.layers.encoder_layer_11.self_attention.out_proj <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>
# vit.encoder.layers.encoder_layer_11.dropout <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_11.ln_2 <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.encoder.layers.encoder_layer_11.mlp <class 'torchvision.models.vision_transformer.MLPBlock'>
# vit.encoder.layers.encoder_layer_11.mlp.0 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_11.mlp.1 <class 'torch.nn.modules.activation.GELU'>
# vit.encoder.layers.encoder_layer_11.mlp.2 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.layers.encoder_layer_11.mlp.3 <class 'torch.nn.modules.linear.Linear'>
# vit.encoder.layers.encoder_layer_11.mlp.4 <class 'torch.nn.modules.dropout.Dropout'>
# vit.encoder.ln <class 'torch.nn.modules.normalization.LayerNorm'>
# vit.heads <class 'torch.nn.modules.container.Sequential'>
# vit.heads.head <class 'torch.nn.modules.linear.Identity'>
# fc1 <class 'torch.nn.modules.linear.Linear'>
# bn1 <class 'torch.nn.modules.batchnorm.BatchNorm1d'>
# relu <class 'torch.nn.modules.activation.ReLU'>
# dropout2 <class 'torch.nn.modules.dropout.Dropout'>
# fc2 <class 'torch.nn.modules.linear.Linear'>

# %%
def validate_model(model, criterion, valid_loader):
    model.eval()
    validation_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for images, labels in valid_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            validation_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    validation_loss = validation_loss / len(valid_loader)
    validation_accuracy = 100 * correct / total
    
    print(f'Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.2f}%')
    return validation_loss, validation_accuracy

# %%
def train_model(model, criterion, optimizer, scheduler, train_loader, valid_loader, num_epochs=25, patience=5):
    model.train()
    best_val_loss = float('inf')
    patience_counter = 0
    history = {
        'train_loss': [],
        'train_accuracy': [],
        'val_loss': [],
        'val_accuracy': []
    }
    
    for epoch in range(num_epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        scheduler.step()
        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = 100 * correct / total
        print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {epoch_loss:.4f}, Training Accuracy: {epoch_accuracy:.2f}%')
        
        val_loss, val_accuracy = validate_model(model, criterion, valid_loader)

        wandb.log({
            "loss": epoch_loss,
            "accuracy": epoch_accuracy,
            "val_loss": val_loss,
            "val_accuracy": val_accuracy
        })

        history['train_loss'].append(epoch_loss)
        history['train_accuracy'].append(epoch_accuracy)
        history['val_loss'].append(val_loss)
        history['val_accuracy'].append(val_accuracy)


        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), 'best_model.pth')
            patience_counter = 0
        else:
            patience_counter += 1
            print(f"No improvement in validation loss for {patience_counter} epochs.")
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break
    return history

# %%
def evaluate_model(model, criterion, test_loader, class_names):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())
    
    test_loss /= len(test_loader)
    accuracy = 100 * correct / total

    prediction_csv(all_labels, all_preds, 'ViT')

    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix - Vision Transformer')
    plt.show()

    wandb.log({"test_loss": test_loss, "test_acc": accuracy})

    print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.2f}%')

# %%
wandb.watch(model, log_freq=100)
# Out:
# []

# %%
history = train_model(model, criterion, optimizer, scheduler, train_loader, valid_loader, num_epochs=25)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history['train_accuracy'], label='Train')
plt.plot(history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history['train_loss'], label='Train')
plt.plot(history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper left')

plt.suptitle('Model Training - Vision Transformer', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 history = train_model(model, criterion, optimizer, scheduler, train_loader, valid_loader, num_epochs=25)
#       3 plt.figure(figsize=(12, 5))
#       5 plt.subplot(1, 2, 1)
#
# Cell In[13], line 22, in train_model(model, criterion, optimizer, scheduler, train_loader, valid_loader, num_epochs, patience)
#      20 outputs = model(images)
#      21 loss = criterion(outputs, labels)
# ---> 22 loss.backward()
#      23 optimizer.step()
#      25 running_loss += loss.item()
#
# File ~/Desktop/VisionTransformer/.venv/lib/python3.11/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/Desktop/VisionTransformer/.venv/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Desktop/VisionTransformer/.venv/lib/python3.11/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# RuntimeError: view size is not compatible with input tensor's size and stride (at least one dimension spans across two contiguous subspaces). Use .reshape(...) instead.

# %%
evaluate_model(model, criterion, test_loader, class_names)

# %%
wandb.finish()
